# %% [markdown]
# # Financial Analytics

# %% [markdown]
# Importing Pandas and reading data

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\anjan\Desktop\Financial Analytics data.csv")

# %%
df
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore
# 0     Reliance Inds.        583436.72           99810.00
# 1                TCS        563709.84           30904.00
# 2          HDFC Bank        482953.59           20581.27
# 3                ITC        320985.27            9772.02
# 4            H D F C        289497.37           16840.51
# ..               ...              ...                ...
# 474      Prime Focus          3031.50             609.61
# 475  Lak. Vilas Bank          3029.57             790.17
# 476            NOCIL          3026.26             249.27
# 477    Orient Cement          3024.32             511.53
# 478  Natl.Fertilizer          3017.07            2840.75
#
# [479 rows x 3 columns]

# %% [markdown]
# Looking for Null values

# %%
df.isnull().sum()
# Out:
# Name                  0
# Mar Cap - Crore       0
# Sales Qtr - Crore    20
# dtype: int64

# %% [markdown]
# Looking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Descriptive Analysis

# %%
df.describe()
# Out:
#        Mar Cap - Crore  Sales Qtr - Crore
# count       479.000000         459.000000
# mean      28043.857119        3807.789412
# std       59464.615831        9989.449987
# min        3017.070000           0.000000
# 25%        4843.575000         534.910000
# 50%        9885.050000        1137.170000
# 75%       23549.900000        2730.195000
# max      583436.720000      110666.930000

# %%
# data sorted by market capitalization 

df.sort_values(by="Mar Cap - Crore",ascending=False).head(10)
# Out:
#              Name  Mar Cap - Crore  Sales Qtr - Crore
# 0  Reliance Inds.        583436.72           99810.00
# 1             TCS        563709.84           30904.00
# 2       HDFC Bank        482953.59           20581.27
# 3             ITC        320985.27            9772.02
# 4         H D F C        289497.37           16840.51
# 5  Hind. Unilever        288265.26            8590.00
# 6   Maruti Suzuki        263493.81           19283.20
# 7         Infosys        248320.35           17794.00
# 8         O N G C        239981.50           22995.88
# 9  St Bk of India        232763.33           57014.08

# %% [markdown]
# Reliance Inds. owns largest market capitalization with 583436.72 Crore

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_sorted =df.sort_values(by="Mar Cap - Crore",ascending=False).head(10)


# Extracting the top 10 companies
top_10_companies = df_sorted

# Creating the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_10_companies['Name'], top_10_companies['Mar Cap - Crore'], color='skyblue')
plt.xlabel('Market Capitalization (Crore)')
plt.ylabel('Company')
plt.title('Top 10 Companies by Market Capitalization')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest market cap at the top
  

# Add data labels

plt.tight_layout()
plt.show()

# %%
#data sorted by quarterly sales

df.sort_values(by="Sales Qtr - Crore",ascending=False).head(10)
# Out:
#                 Name  Mar Cap - Crore  Sales Qtr - Crore
# 14           I O C L        178017.48          110666.93
# 0     Reliance Inds.        583436.72           99810.00
# 23       Tata Motors        117071.87           74156.07
# 27           B P C L         98278.00           60616.36
# 54           H P C L         58034.78           57474.25
# 9     St Bk of India        232763.33           57014.08
# 121   Rajesh Exports         23495.54           41304.84
# 40        Tata Steel         73376.14           32464.14
# 1                TCS        563709.84           30904.00
# 13   Larsen & Toubro        180860.74           28747.45

# %% [markdown]
# Quarterly sales is more in I O C L with 110666.93 Crore and then comes Reliance Inds. with 99810.00 Crores

# %%
df_sorted_2 = df.sort_values(by="Sales Qtr - Crore", ascending=False).head(10)

# Extracting the top 10 companies
top_sales = df_sorted_2

# Creating the horizontal bar chart
plt.figure(figsize=(15, 6))
sns.barplot(x=top_sales['Name'], y=top_sales['Sales Qtr - Crore'], color='skyblue')
plt.xlabel('Company Name')
plt.ylabel('Quarterly Sales')
plt.title('Top 10 Companies by Quarterly Sales')

# Invert y-axis to have the highest market cap at the top
  
# Add data labels
plt.show()

# %%
# to see top 10 companies 

df.sort_values(by=["Mar Cap - Crore","Sales Qtr - Crore"],ascending=False).head(10)
# Out:
#              Name  Mar Cap - Crore  Sales Qtr - Crore
# 0  Reliance Inds.        583436.72           99810.00
# 1             TCS        563709.84           30904.00
# 2       HDFC Bank        482953.59           20581.27
# 3             ITC        320985.27            9772.02
# 4         H D F C        289497.37           16840.51
# 5  Hind. Unilever        288265.26            8590.00
# 6   Maruti Suzuki        263493.81           19283.20
# 7         Infosys        248320.35           17794.00
# 8         O N G C        239981.50           22995.88
# 9  St Bk of India        232763.33           57014.08

# %%
plt.figure(figsize=(15, 8))  

# Sorting the DataFrame
df_sorted = df.sort_values(by="Mar Cap - Crore", ascending=False).head(10)
df_sorted_2 = df.sort_values(by="Sales Qtr - Crore", ascending=False).head(10)

# Extracting top companies
top_sales = df_sorted_2
top_10_companies = df_sorted

# Plotting market capitalization on the primary y-axis
plt.bar(top_10_companies["Name"], top_10_companies["Mar Cap - Crore"], color='b')
plt.ylabel('Market Capitalization (Crore)', color='b')
plt.tick_params(axis='y', colors='b')

# Creating a secondary y-axis for quarterly sales
plt.twinx()
plt.plot(top_10_companies["Name"], top_10_companies["Sales Qtr - Crore"], color='r', marker='o')
plt.ylabel('Quarterly Sales (Crore)', color='r')
plt.tick_params(axis='y', colors='r')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90, fontsize=10)

# Title and labels
plt.title('Market Capitalization and Quarterly Sales')
plt.xlabel('Company')

plt.show()

# %% [markdown]
# Finding Correlation between qauarterly sales and market capitalization

# %%
df.corr()
# Out:
# C:\Users\anjan\AppData\Local\Temp\ipykernel_9384\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Mar Cap - Crore  Sales Qtr - Crore
# Mar Cap - Crore           1.000000           0.624409
# Sales Qtr - Crore         0.624409           1.000000

# %% [markdown]
# We cant say that quarterly sales and market capitalization is  highly correlated since their correlation value is less then 0.7

# %%
plt.figure(figsize=(4, 3))
sns.heatmap(data=df.corr())
plt.show()
# Out:
# C:\Users\anjan\AppData\Local\Temp\ipykernel_9384\563710189.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())

# %%
plt.figure(figsize=(10, 8))
plt.scatter(df["Sales Qtr - Crore"],df["Mar Cap - Crore"] , alpha=0.5)

# Annotate each point with the corresponding company name

plt.title('Relationship between Market Capitalization and Quarterly Sales')
plt.xlabel('Quarterly Sales (Crore)')
plt.ylabel('Market Capitalization (Crore)')
plt.grid(True)
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# Histogram for Market Capitalization
sns.histplot(df['Mar Cap - Crore'], ax=axes[0], kde=True, color='skyblue')
axes[0].set_title('Distribution of Market Capitalization')
axes[0].set_xlabel('Market Capitalization(In Crores)')
axes[0].set_ylabel('Frequency')

# Histogram for Quarterly Sales
sns.histplot(df['Sales Qtr - Crore'], ax=axes[1], kde=True, color='salmon')
axes[1].set_title('Distribution of Quarterly Sales')
axes[1].set_xlabel('Quarterly Sales(In Crores)')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Most number of companies have market capitalization below 100000 cores and quarterly sales below 20000 crores.
